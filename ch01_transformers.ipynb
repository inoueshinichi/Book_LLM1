# %% [markdown]
# <a href="https://colab.research.google.com/github/inoueshinichi/Book_LLM1/blob/main/ch01_transformers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !cat /etc/os-release | head -n 2
# Out:
# PRETTY_NAME="Ubuntu 22.04.3 LTS"
# NAME="Ubuntu"

# %%
# !pip install transformers[ja,sentencepiece,torch]
# Out:
# Requirement already satisfied: transformers[ja,sentencepiece,torch] in /usr/local/lib/python3.10/dist-packages (4.44.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers[ja,sentencepiece,torch]) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers[ja,sentencepiece,torch]) (0.24.7)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers[ja,sentencepiece,torch]) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers[ja,sentencepiece,torch]) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers[ja,sentencepiece,torch]) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers[ja,sentencepiece,torch]) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers[ja,sentencepiece,torch]) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers[ja,sentencepiece,torch]) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers[ja,sentencepiece,torch]) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers[ja,sentencepiece,torch]) (4.66.5)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from transformers[ja,sentencepiece,torch]) (3.20.3)
# Requirement already satisfied: sentencepiece!=0.1.92,>=0.1.91 in /usr/local/lib/python3.10/dist-packages (from transformers[ja,sentencepiece,torch]) (0.2.0)
# Collecting fugashi>=1.0 (from transformers[ja,sentencepiece,torch])
#   Downloading fugashi-1.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.0 kB)
# Collecting ipadic<2.0,>=1.0.0 (from transformers[ja,sentencepiece,torch])
#   Downloading ipadic-1.0.0.tar.gz (13.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 115.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting rhoknp<1.3.1,>=1.1.0 (from transformers[ja,sentencepiece,torch])
#   Downloading rhoknp-1.3.0-py3-none-any.whl.metadata (7.8 kB)
# Collecting sudachidict-core>=20220729 (from transformers[ja,sentencepiece,torch])
#   Downloading SudachiDict_core-20240716-py3-none-any.whl.metadata (2.5 kB)
# Collecting sudachipy>=0.6.6 (from transformers[ja,sentencepiece,torch])
#   Downloading SudachiPy-0.6.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting unidic>=1.0.2 (from transformers[ja,sentencepiece,torch])
#   Downloading unidic-1.1.0.tar.gz (7.7 kB)
#   Preparing metadata (setup.py) ... done
# Collecting unidic-lite>=1.0.7 (from transformers[ja,sentencepiece,torch])
#   Downloading unidic-lite-1.0.8.tar.gz (47.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.4/47.4 MB 46.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: accelerate>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from transformers[ja,sentencepiece,torch]) (0.34.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from transformers[ja,sentencepiece,torch]) (2.4.1+cu121)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.21.0->transformers[ja,sentencepiece,torch]) (5.9.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers[ja,sentencepiece,torch]) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers[ja,sentencepiece,torch]) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->transformers[ja,sentencepiece,torch]) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->transformers[ja,sentencepiece,torch]) (3.4.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[ja,sentencepiece,torch]) (3.1.4)
# Collecting wasabi<1.0.0,>=0.6.0 (from unidic>=1.0.2->transformers[ja,sentencepiece,torch])
#   Downloading wasabi-0.10.1-py3-none-any.whl.metadata (28 kB)
# Collecting plac<2.0.0,>=1.1.3 (from unidic>=1.0.2->transformers[ja,sentencepiece,torch])
#   Downloading plac-1.4.3-py2.py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[ja,sentencepiece,torch]) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[ja,sentencepiece,torch]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[ja,sentencepiece,torch]) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[ja,sentencepiece,torch]) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->transformers[ja,sentencepiece,torch]) (3.0.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->transformers[ja,sentencepiece,torch]) (1.3.0)
# Downloading fugashi-1.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (600 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 600.9/600.9 kB 4.2 MB/s eta 0:00:00
# Downloading rhoknp-1.3.0-py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 8.6 MB/s eta 0:00:00
# Downloading SudachiDict_core-20240716-py3-none-any.whl (72.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 MB 28.7 MB/s eta 0:00:00
# Downloading SudachiPy-0.6.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 70.7 MB/s eta 0:00:00
# Downloading plac-1.4.3-py2.py3-none-any.whl (22 kB)
# Downloading wasabi-0.10.1-py3-none-any.whl (26 kB)
# Building wheels for collected packages: ipadic, unidic, unidic-lite
#   Building wheel for ipadic (setup.py) ... done
#   Created wheel for ipadic: filename=ipadic-1.0.0-py3-none-any.whl size=13556704 sha256=25e2b81f14b96bd53d61b59b473af08c9b6808703920272d3d01a21fc5cece90
#   Stored in directory: /root/.cache/pip/wheels/5b/ea/e3/2f6e0860a327daba3b030853fce4483ed37468bbf1101c59c3
#   Building wheel for unidic (setup.py) ... done
#   Created wheel for unidic: filename=unidic-1.1.0-py3-none-any.whl size=7403 sha256=5770d58a7d75141eacd850965c729d92be85469c84debe309be32e990fe346b7
#   Stored in directory: /root/.cache/pip/wheels/7a/72/72/1f3d654c345ea69d5d51b531c90daf7ba14cc555eaf2c64ab0
#   Building wheel for unidic-lite (setup.py) ... done
#   Created wheel for unidic-lite: filename=unidic_lite-1.0.8-py3-none-any.whl size=47658818 sha256=ab0e4ca647426cb87a79232832510e356c3297d74ec86018d6d1c0d92cc0bc35
#   Stored in directory: /root/.cache/pip/wheels/89/e8/68/f9ac36b8cc6c8b3c96888cd57434abed96595d444f42243853
# Successfully built ipadic unidic unidic-lite
# Installing collected packages: wasabi, unidic-lite, sudachipy, plac, ipadic, sudachidict-core, rhoknp, fugashi, unidic
#   Attempting uninstall: wasabi
#     Found existing installation: wasabi 1.1.3
#     Uninstalling wasabi-1.1.3:
#       Successfully uninstalled wasabi-1.1.3
# Successfully installed fugashi-1.3.2 ipadic-1.0.0 plac-1.4.3 rhoknp-1.3.0 sudachidict-core-20240716 sudachipy-0.6.8 unidic-1.1.0 unidic-lite-1.0.8 wasabi-0.10.1

# %%
from transformers import pipeline

# %% [markdown]
# 1.1.1 文書分類(document classification)

# %%
text_classification_pipeline = pipeline(
    model="llm-book/bert-base-japanese-v3-marc_ja"
)

positive_text = '世界には言葉がわからなくても感動する音楽がある。'

# 極性を予測(極性分析)
print(text_classification_pipeline(positive_text)[0])
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/843 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/445M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/609 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/231k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# {'label': 'positive', 'score': 0.9993619322776794}

# %%
negative_text = "世界には言葉が出ないほどひどい音楽がある。"

# 極性を予測
print(text_classification_pipeline(negative_text)[0])
# Out:
# {'label': 'negative', 'score': 0.9859846830368042}

# %% [markdown]
# 1.1.2 自然言語推論</br>
# 二つのテキストの論理関係を予測するタスク

# %%
nli_pipeline = pipeline(model='llm-book/bert-base-japanese-v3-jnli')

text = '二人の男性がジェット機を見ています'
entailment_text = 'ジェット機を見ているい人が二人います'

# textとentailment_text(含意)の論理関係を予測
print(nli_pipeline({"text": text, "text_pair": entailment_text}))
# Out:
# config.json:   0%|          | 0.00/907 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/445M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/606 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/231k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# {'label': 'entailment', 'score': 0.9962222576141357}

# %%
contradiction_text = '二人の男性が飛んでいます'

# textとentailment_text(矛盾)の論理関係を予測
print(nli_pipeline({"text": text, "text_pair": contradiction_text}))
# Out:
# {'label': 'contradiction', 'score': 0.9990535378456116}

# %%
neutral_text = "2人の男性が、白い飛行機を眺めています"

# textとentailment_text(中立)の論理関係を予測
print(nli_pipeline({"text": text, "text_pair": neutral_text}))
# Out:
# {'label': 'neutral', 'score': 0.9959145188331604}

# %% [markdown]
# 1.1.3 意味的類似度計算(semantic textual similarity; STS)

# %%
text_sim_pipeline = pipeline(
    model="llm-book/bert-base-japanese-v3-jsts",
    function_to_apply="none",
)

text = "川べりでサーフボードを持った人たちがいます"
sim_text = "サーファーたちが川べりに立っています"

# textとsim_textの類似度を計算
result = text_sim_pipeline({"text": text, "text_pair": sim_text})
print(result["score"])
# Out:
# config.json:   0%|          | 0.00/796 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/445M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/606 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/231k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# 3.5703563690185547

# %%
dissim_text = "トレイの壁に黒いタオルが掛けられています"

# textとdissim_textの類似度を計算
result = text_sim_pipeline({"text": text, "text_pair": dissim_text})
print(result['score'])
# Out:
# 0.08240910619497299

# %%
from torch.nn.functional import cosine_similarity

sim_enc_pipeline = pipeline(
    model="llm-book/bert-base-japanese-v3-unsup-simcse-jawiki",
    task='feature-extraction',
)

# textとsim_textのベクトルを獲得
text_emb = sim_enc_pipeline(text, return_tensors=True)[0][0]
sim_emb = sim_enc_pipeline(sim_text, return_tensors=True)[0][0]
dissim_emb = sim_enc_pipeline(dissim_text, return_tensors=True)[0][0]

# textとsim_textの類似度を計算
sim_pair_score = cosine_similarity(text_emb, sim_emb, dim=0)
print(sim_pair_score.item())

# textとdissim_textの類似度を計算
dissim_pair_score = cosine_similarity(text_emb, dissim_emb, dim=0)
print(dissim_pair_score.item())
# Out:
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# 0.8568587303161621
# 0.45702308416366577

# %% [markdown]
# 1.1.4 固有表現認識(named entity recognition; NER)</br>
# テキストに含まれる固有表現を抽出するタスク

# %%
from pprint import pprint

ner_pipeline = pipeline(
    model="llm-book/bert-base-japanese-v3-ner-wikipedia-dataset",
    aggregation_strategy="simple"
)

text = "大谷翔平は岩手県水沢市出身のプロ野球選手"
# textの中の固有表現を抽出
pprint(ner_pipeline(text))
# Out:
# config.json:   0%|          | 0.00/1.93k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/443M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/529 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/231k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# [{'end': None,
#   'entity_group': '人名',
#   'score': 0.99823624,
#   'start': None,
#   'word': '大谷 翔平'},
#  {'end': None,
#   'entity_group': '地名',
#   'score': 0.9986874,
#   'start': None,
#   'word': '岩手 県 水沢 市'}]

# %% [markdown]
# 1.1.5 要約生成(summarization generation)

# %%
text2text_pipeline = pipeline(
    model="llm-book/t5-base-long-livedoor-news-corpus"
)

article = ("ついに始まった三連休。テレビを見ながら過ごしている人もおおいのではないだろうか。"
        "今夜のおすすめは何といってもNHKスペシャル「世界を変えた男スティーブ・ジョブズ」だ。"
        "実は知らない人も多いジョブズ氏の養子に出された生い立ちや、アップル社から一時追放されるなどの経験。"
        "そして、彼が追い求めた理想の未来とはなんだったのだろうか。ファンならずとも気になる内容になっている")

print(text2text_pipeline(article)[0]["generated_text"])
# Out:
# config.json:   0%|          | 0.00/768 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/990M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/142 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/2.38k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/798k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.43M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.20k [00:00<?, ?B/s]
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1258: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# 今夜はNHKスペシャル「世界を変えた男スティーブ・ジョブズ」

# %% [markdown]
# 1.2 transformersの基本的な使い方</br>
# 1. AutoClass
# 2. AutoTokenizer

# %%
from transformers import AutoTokenizer

# AutoTokenizerでトークナイザをロードする
tokenizer = AutoTokenizer.from_pretrained('abeja/gpt2-large-japanese')
# 入力文をトークンに分割する
tokenizer.tokenize("今日は天気が良いので")
# Out:
# tokenizer_config.json:   0%|          | 0.00/282 [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/784k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/153 [00:00<?, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# ['▁', '今日', 'は', '天気', 'が良い', 'の', 'で']

# %%
from transformers import AutoModelForCausalLM

# 生成を行うモデルであるAutoModelForCausealLM
model = AutoModelForCausalLM.from_pretrained(
    "abeja/gpt2-large-japanese"
)

# トークナイザを使ってモデルへの入力を作る
inputs = tokenizer("今日は天気が良いので", return_tensors="pt")

print(f"inputs: {inputs}")

# 後続のテキストを予測
outputs = model.generate(
    **inputs,
    max_length=15, # 生成するトークンの最大長
    pad_token_id=tokenizer.pad_token_id # パディングのトークンIDを指定
)

print(f"outputs: {outputs}")

# generate関数の出力をテキストに変換する
generated_text = tokenizer.decode(
    outputs[0], skip_special_tokens=True
)

print(generated_text)
# Out:
# config.json:   0%|          | 0.00/974 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/3.04G [00:00<?, ?B/s]
# inputs: {'input_ids': tensor([[    7,  4639,    15, 17110, 16958,    10,    20,     2]]), 'attention_mask': tensor([[1, 1, 1, 1, 1, 1, 1, 1]])}
# outputs: tensor([[    7,  4639,    15, 17110, 16958,    10,    20,     2,   346,    20,
#            196, 16002, 11671,  3426,     9]])
# 今日は天気が良いので外でお弁当を食べました。
